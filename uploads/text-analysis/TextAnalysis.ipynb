# %%
import nltk
import pyodide_http
pyodide_http.patch_all()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nltk.download('all-corpora')
# Out:
# [nltk_data] Downloading collection 'all-corpora'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package pil to /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package qc to /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package rte to /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/pyodide/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all-corpora
# True

# %%
nltk.download('genesis')
nltk.download('gutenberg')
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('treebank')
nltk.download('webtext')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package genesis to /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/genesis.zip.
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package inaugural to
# [nltk_data]     /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/inaugural.zip.
# [nltk_data] Downloading package nps_chat to /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/nps_chat.zip.
# [nltk_data] Downloading package treebank to /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package webtext to /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/webtext.zip.
# [nltk_data] Downloading package wordnet to /home/pyodide/nltk_data...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/pyodide/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.book import *

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
type(text3)
# Out:
# nltk.text.Text

# %%
text3[0:10]
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth']

# %%
text4.concordance("love")
# Out:
# Displaying 25 of 56 matches:
# n never hear but with veneration and love , from a retreat which I had chosen
# h every satisfaction which an ardent love for my country can inspire , since t
# , can so well deserve our esteem and love ? There may be little solidity in an
#  with the same ardent patriotism and love of liberty to independence and peace
# or their personal attachments ; if a love of virtuous men of all parties and d
# all parties and denominations ; if a love of science and letters and a wish to
# ction to elective governments ; if a love of equal laws , of justice , and hum
# h , temperance , gratitude , and the love of man ; acknowledging and adoring a
# o the first place in his country ' s love and destined for him the fairest pag
#  rights of men , breathing an ardent love of liberty and independence , and oc
# stice . They have been dictated by a love of peace , of economy , and an earne
# session of the human mind , like the love of gold it becomes insatiable . It i
# he same effects , and as long as the love of power is a dominant passion of th
# have examples of republics where the love of country and of liberty at one tim
# at I owe my election to the inherent love for the Constitution and the Union w
# s that when this has decayed and the love of money has usurped its place , alt
# also be wise to consider whether the love for the Union which now animates our
# em . To those , however , who really love the Union may I not speak ? Before e
#  We can not overestimate the fervent love of liberty , the intelligent courage
# r position and defended by our known love of justice and by our power . It is
#  people a spirit of fraternity and a love of righteousness and peace . This oc
# in everything except courage and the love of liberty , that then fringed our A
# ent more worthy of their respect and love or a land so magnificent in extent ,
# bequeathed to us as an object of our love and veneration . It perverts the pat
# itutions which we enjoy . The people love and will sustain these institutions

# %%
text4.similar("love")
# Out:
# people freedom time hope confidence government union peace strength
# purpose country nation future world way security congress spirit
# desire safety

# %%
text4.similar("patriotism")
# Out:
# peace people government honor duties duty confidence union power laws
# spirit freedom country will prosperity right security opinions law
# protection

# %%
text1.dispersion_plot(["whale", "monster"])
# Out:
# /lib/python3.11/site-packages/nltk/draw/__init__.py:15: UserWarning: nltk.draw package not loaded (please install Tkinter library).
#   warnings.warn("nltk.draw package not loaded (please install Tkinter library).")

# %%
text2.dispersion_plot(["Brandon","Elinor","Lucy","Edward","Marianne","Margaret"])

# %%
text1.count("whale")
# Out:
# 906

# %%
text1.count("Whale")
# Out:
# 282

# %%
text1.count("WHALE")
# Out:
# 38

# %%
string = "ELI5"
print(string.isalpha())
print(string.lower())
# Out:
# False
# eli5

# %%
text1_tokens = []
for t in text1:
    if t.isalpha():
        t = t.lower()
        text1_tokens.append(t)

# %%
text1_tokens_LC = [t.lower() for t in text1 if t.isalpha()]

# %%
text1_tokens == text1_tokens_LC
# Out:
# True

# %%
text1_tokens.count("whale")
# Out:
# 1226

# %%
len(text1)
# Out:
# 260819

# %%
len(text1_tokens)
# Out:
# 218361

# %%
list_example = [2,3,4,12,3,12,3,1,32]

# %%
set(list_example)
# Out:
# {1, 2, 3, 4, 12, 32}

# %%
len(set(text1_tokens))
# Out:
# 16948

# %%
len(set(text1_tokens)) / len(text1_tokens)
# Out:
# 0.07761459234936642

# %%
text = text1_tokens
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 text = text1_tokens
# ----> 2 wordcloud = WordCloud().generate(text)
#       3 plt.imshow(wordcloud)
#
# File /lib/python3.11/site-packages/wordcloud/wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# File /lib/python3.11/site-packages/wordcloud/wordcloud.py:620, in WordCloud.generate_from_text(self, text)
#     603 def generate_from_text(self, text):
#     604     """Generate wordcloud from text.
#     605
#     606     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618     self
#     619     """
# --> 620     words = self.process_text(text)
#     621     self.generate_from_frequencies(words)
#     622     return self
#
# File /lib/python3.11/site-packages/wordcloud/wordcloud.py:582, in WordCloud.process_text(self, text)
#     579 pattern = r"\w[\w']*" if self.min_word_length <= 1 else r"\w[\w']+"
#     580 regexp = self.regexp if self.regexp is not None else pattern
# --> 582 words = re.findall(regexp, text, flags)
#     583 # remove 's
#     584 words = [word[:-2] if word.lower().endswith("'s") else word
#     585          for word in words]
#
# File /lib/python311.zip/re/__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object, got 'list'

# %%
text = str(text1_tokens)
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud)

# %%
from nltk.corpus import stopwords

# %%
stops = stopwords.words('english')

# %%
print(stops)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
text1_stops = []
for t in text1_tokens:
    if t not in stops:
        text1_stops.append(t)

# %%
text1_stops = [t for t in text1_tokens if t not in stops]

# %%
print(text1_stops[:30])
# Out:
# ['moby', 'dick', 'herman', 'melville', 'etymology', 'supplied', 'late', 'consumptive', 'usher', 'grammar', 'school', 'pale', 'usher', 'threadbare', 'coat', 'heart', 'body', 'brain', 'see', 'ever', 'dusting', 'old', 'lexicons', 'grammars', 'queer', 'handkerchief', 'mockingly', 'embellished', 'gay', 'flags']

# %%
len(text1_stops)
# Out:
# 110459

# %%
text = str(text1_stops)
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud)

# %%
string_text = ' '.join(text1_stops)

# %%
wordcloud = WordCloud().generate(string_text)
plt.imshow(wordcloud)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
wordnet_lemmatizer = WordNetLemmatizer()
porter_stemmer = PorterStemmer()

# %%
print(wordnet_lemmatizer.lemmatize('berry'))
print(wordnet_lemmatizer.lemmatize('berries'))
print(porter_stemmer.stem('berry'))
print(porter_stemmer.stem('berries'))
# Out:
# berry
# berry
# berri
# berri

# %%
wordnet_lemmatizer.lemmatize("better")
# Out:
# 'better'

# %%
wordnet_lemmatizer.lemmatize("better", pos='a')
# Out:
# 'good'

# %%
print(wordnet_lemmatizer.lemmatize('abandon'))
print(wordnet_lemmatizer.lemmatize('abandoned'))
print(wordnet_lemmatizer.lemmatize('abandonly'))
print(wordnet_lemmatizer.lemmatize('abandonment'))
print(porter_stemmer.stem('abandon'))
print(porter_stemmer.stem('abandoned'))
print(porter_stemmer.stem('abandonedly'))
print(porter_stemmer.stem('abandonment'))
# Out:
# abandon
# abandoned
# abandonly
# abandonment
# abandon
# abandon
# abandonedli
# abandon

# %%
text1_clean = []
for t in text1_stops:
    t_stem = porter_stemmer.stem(t)
    t_lem = wordnet_lemmatizer.lemmatize(t_stem)
    text1_clean.append(t_lem)

# %%
len(text1_clean)
# Out:
# 110459

# %%
text1_clean_test = []
for t in text1_stops:
    t_lem = wordnet_lemmatizer.lemmatize(t)
    t_stem = porter_stemmer.stem(t_lem)
    text1_clean_test.append(t_stem)

# %%
len(text1_clean_test)
# Out:
# 110459

# %%
len(set(text1_clean))
# Out:
# 10489

# %%
print(len(text1_clean))
print(len(set(text1_clean)))
# Out:
# 110459
# 10489

# %%
sorted(set(text1_clean))[:30]
# Out:
# ['aba',
#  'aback',
#  'abaft',
#  'abandon',
#  'abandonedli',
#  'abash',
#  'abat',
#  'abbrevi',
#  'abe',
#  'abeam',
#  'abednego',
#  'abel',
#  'abhor',
#  'abhorr',
#  'abid',
#  'abil',
#  'abjectli',
#  'abjectu',
#  'abl',
#  'ablut',
#  'aboard',
#  'abod',
#  'abomin',
#  'aborigin',
#  'abort',
#  'abound',
#  'aboundingli',
#  'abraham',
#  'abreast',
#  'abridg']

# %%
my_dist = FreqDist(text1_clean)

# %%
type(my_dist)
# Out:
# nltk.probability.FreqDist

# %%
my_dist.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
my_dist.most_common(20)
# Out:
# [('whale', 1626),
#  ('one', 941),
#  ('like', 661),
#  ('ship', 623),
#  ('upon', 566),
#  ('ye', 547),
#  ('sea', 542),
#  ('man', 541),
#  ('ahab', 512),
#  ('boat', 483),
#  ('head', 466),
#  ('seem', 463),
#  ('old', 450),
#  ('time', 449),
#  ('would', 432),
#  ('though', 384),
#  ('hand', 367),
#  ('look', 366),
#  ('captain', 353),
#  ('yet', 345)]

# %%
b_words = ['god', 'apostle', 'angel','meme']

# %%
my_list = []
for word in b_words:
    if word in text1_clean:
        my_list.append(word)
    else:
        pass

# %%
print(my_list)
# Out:
# ['god', 'angel']

# %%
from urllib.request import urlopen

# %%
my_url = "https://raw.githubusercontent.com/GITenberg/Don-Quixote_996/master/996.txt"

# %%
file = urlopen(my_url)

raw = file.read()

# %%
don = raw.decode()

# %%
type(don)
# Out:
# str

# %%
don[0:100]
# Out:
# 'The Project Gutenberg EBook of Don Quixote, by Miguel de Cervantes\r\n\r\nThis eBook is for the use of a'

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/pyodide/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
don_tokens = nltk.word_tokenize(don)

# %%
len(don_tokens)
# Out:
# 496537

# %%
don_tokens[:10]
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Don',
#  'Quixote',
#  ',',
#  'by',
#  'Miguel']

# %%
dq_text = don_tokens[320:]

# %%
print(dq_text[:30])
# Out:
# ['WHAT', 'A', 'GOATHERD', 'RELATED', 'TO', 'THOSE', 'WITH', 'DON', 'QUIXOTE', 'CHAPTER', 'XIII', 'IN', 'WHICH', 'IS', 'ENDED', 'THE', 'STORY', 'OF', 'THE', 'SHEPHERDESS', 'MARCELA', ',', 'WITH', 'OTHER', 'INCIDENTS', 'CHAPTER', 'XIV', 'WHEREIN', 'ARE', 'INSERTED']

# %%
dq_text.similar("WINDMILLS")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 dq_text.similar("WINDMILLS")
#
# AttributeError: 'list' object has no attribute 'similar'

# %%
dq_nltk_text = nltk.Text(dq_text)

# %%
type(dq_nltk_text)
# Out:
# nltk.text.Text

# %%
dq_nltk_text.similar("windmills")
# Out:
# other curate same town duke inn body barber man matter letter night
# duchess ground earth story gentleman world one truth
